# %%
import requests
import pandas as pd
import io
from zipfile import ZipFile, BadZipFile

# %%
columns = ["Kod stacji", "Nazwa stacji", "Rok", "Miesiąc", "Dzień", "Suma dobowa opadów [mm]", "Status pomiaru SMDB",
           "Rodzaj opadu [S/W/ ]", "Wysokość pokrywy śnieżnej [cm]", "Status pomiaru PKSN", "Wysokość świeżospałego śniegu [cm]",
           "Status pomiaru HSS", "Gatunek śniegu  [kod]", "Status pomiaru GATS",  "Rodzaj pokrywy śnieżnej [kod]", "Status pomiaru RPSN" ]
dane = pd.DataFrame(columns = columns)
dane
# Out:
# Empty DataFrame
# Columns: [Kod stacji, Nazwa stacji, Rok, Miesiąc, Dzień, Suma dobowa opadów [mm], Status pomiaru SMDB, Rodzaj opadu [S/W/ ], Wysokość pokrywy śnieżnej [cm], Status pomiaru PKSN, Wysokość świeżospałego śniegu [cm], Status pomiaru HSS, Gatunek śniegu  [kod], Status pomiaru GATS, Rodzaj pokrywy śnieżnej [kod], Status pomiaru RPSN]
# Index: []

# %%
lata = ["1991_1995/", "1996_2000/", "2001/", "2002/", "2003/", "2004/", "2005/", "2006/", "2007/", "2008/", 
        "2009/", "2010/", "2011/", "2012/", "2013/", "2014/", "2015/", "2016/", "2017/", "2018/", "2019/",
        "2020/", "2021/", "2022/", "2023/", "2024/"]

base_url = "https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/opad/"

# Iteracja przez lata
for rok in lata:
    if "_" in rok:
        rok_start, rok_end = map(int, rok.rstrip("/").split("_"))
        url = base_url + rok + f"{rok_start}_o.zip"
        response = requests.get(url)
        #print(f"{url}")
        print(f"Tu jestem 1 - response_code = {response.status_code}, rok = {rok}")
        # Sprawdzenie, czy żądanie się powiodło
        if response.status_code == 200:
            # Wczytanie danych z pliku ZIP do ramki danych
            try:
                with ZipFile(io.BytesIO(response.content)) as z:
                    for file_name in z.namelist():
                        with z.open(file_name) as f:
                            # Ustawienie odpowiedniego kodowania
                            df = pd.read_csv(f, delimiter=",", header=None, names=columns, encoding="latin-1")
                            dane = pd.concat([dane, df], ignore_index=True)
            except BadZipFile:
                    print(f"Bad ZIP file for {rok}")
    else:
        for miesiac in range(1, 13):
            # Pobieranie pliku ZIP
            url = base_url + rok + f"{rok[:-1]}_{miesiac:02d}_o.zip"
            response = requests.get(url)
            #print(f"Tu jestem 2 - response_code = {response.status_code}, rok = {rok}, miesiac = {miesiac}")
            # Sprawdzenie, czy żądanie się powiodło
            if response.status_code == 200:
                # Wczytanie danych z pliku ZIP do ramki danych
                try:
                    with ZipFile(io.BytesIO(response.content)) as z:
                        for file_name in z.namelist():
                            with z.open(file_name) as f:
                                # Ustawienie odpowiedniego kodowania
                                df = pd.read_csv(f, delimiter=",", header=None, names=columns, encoding="latin-1")
                                dane = pd.concat([dane, df], ignore_index=True)
                except BadZipFile:
                    print(f"Bad ZIP file for {rok}")
# Out:
# Tu jestem 1 - response_code = 200, rok = 1991_1995/
# C:\Users\Kowalski Krzysztof\AppData\Local\Temp\ipykernel_7616\3823208400.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dane = pd.concat([dane, df], ignore_index=True)
# Tu jestem 1 - response_code = 200, rok = 1996_2000/
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2001/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2002/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2003/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2004/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2005/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2006/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2007/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2008/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2009/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2010/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2011/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2012/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2013/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2014/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2015/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2016/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2017/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2018/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2019/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2020/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2021/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 3
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 4
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 11
# Tu jestem 2 - response_code = 200, rok = 2022/, miesiac = 12
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 2
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 3
# Bad ZIP file for 2023/
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 4
# Bad ZIP file for 2023/
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 5
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 6
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 7
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 8
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 9
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 10
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 11
# Bad ZIP file for 2023/
# Tu jestem 2 - response_code = 200, rok = 2023/, miesiac = 12
# Bad ZIP file for 2023/
# Tu jestem 2 - response_code = 200, rok = 2024/, miesiac = 1
# Tu jestem 2 - response_code = 200, rok = 2024/, miesiac = 2
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 3
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 4
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 5
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 6
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 7
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 8
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 9
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 10
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 11
# Tu jestem 2 - response_code = 404, rok = 2024/, miesiac = 12
#   Kod stacji Nazwa stacji   Rok Miesiąc Dzień  Suma dobowa opadów [mm]  \
# 0  249180020   WARSZOWICE  1991       1     2                      5.5
# 1  249180020   WARSZOWICE  1991       1     3                      3.5
# 2  249180020   WARSZOWICE  1991       1     4                      1.9
# 3  249180020   WARSZOWICE  1991       1     7                      3.3
# 4  249180020   WARSZOWICE  1991       1    10                      0.0
#
#    Status pomiaru SMDB Rodzaj opadu [S/W/ ] Wysokość pokrywy śnieżnej [cm]  \
# 0                  NaN                    W                              0
# 1                  NaN                    W                              0
# 2                  NaN                    W                              0
# 3                  NaN                    W                              0
# 4                  NaN                    W                              0
#
#    Status pomiaru PKSN Wysokość świeżospałego śniegu [cm]  Status pomiaru HSS  \
# 0                  8.0                                  0                 8.0
# 1                  8.0                                  0                 8.0
# 2                  8.0                                  0                 8.0
# 3                  8.0                                  0                 8.0
# 4                  8.0                                  0                 8.0
#
#    Gatunek śniegu  [kod]  Status pomiaru GATS Rodzaj pokrywy śnieżnej [kod]  \
# 0                    NaN                  8.0                           NaN
# 1                    NaN                  8.0                           NaN
# 2                    NaN                  8.0                           NaN
# 3                    NaN                  8.0                           NaN
# 4                    NaN                  8.0                           NaN
#
#    Status pomiaru RPSN
# 0                  8.0
# 1                  8.0
# 2                  8.0
# 3                  8.0
# 4                  8.0

# %%
dane
# Out:
#         Kod stacji Nazwa stacji   Rok Miesiąc Dzień  Suma dobowa opadów [mm]  \
# 0        249180020   WARSZOWICE  1991       1     2                      5.5
# 1        249180020   WARSZOWICE  1991       1     3                      3.5
# 2        249180020   WARSZOWICE  1991       1     4                      1.9
# 3        249180020   WARSZOWICE  1991       1     7                      3.3
# 4        249180020   WARSZOWICE  1991       1    10                      0.0
# ...            ...          ...   ...     ...   ...                      ...
# 3799790  254230020        SEJNY  2024       2    23                      5.3
# 3799791  254230020        SEJNY  2024       2    24                      0.1
# 3799792  254230020        SEJNY  2024       2    26                      5.1
# 3799793  254230020        SEJNY  2024       2    27                      0.9
# 3799794  254230020        SEJNY  2024       2    28                      5.8
#
#          Status pomiaru SMDB Rodzaj opadu [S/W/ ]  \
# 0                        NaN                    W
# 1                        NaN                    W
# 2                        NaN                    W
# 3                        NaN                    W
# 4                        NaN                    W
# ...                      ...                  ...
# 3799790                  NaN                    W
# 3799791                  NaN                    W
# 3799792                  NaN                    W
# 3799793                  NaN                    W
# 3799794                  NaN                    W
#
#         Wysokość pokrywy śnieżnej [cm]  Status pomiaru PKSN  \
# 0                                    0                  8.0
# 1                                    0                  8.0
# 2                                    0                  8.0
# 3                                    0                  8.0
# 4                                    0                  8.0
# ...                                ...                  ...
# 3799790                              0                  9.0
# 3799791                              0                  9.0
# 3799792                              0                  9.0
# 3799793                              0                  9.0
# 3799794                              0                  9.0
#
#         Wysokość świeżospałego śniegu [cm]  Status pomiaru HSS  \
# 0                                        0                 8.0
# 1                                        0                 8.0
# 2                                        0                 8.0
# 3                                        0                 8.0
# 4                                        0                 8.0
# ...                                    ...                 ...
# 3799790                                  0                 8.0
# 3799791                                  0                 8.0
# 3799792                                  0                 8.0
# 3799793                                  0                 8.0
# 3799794                                  0                 8.0
#
#          Gatunek śniegu  [kod]  Status pomiaru GATS  \
# 0                          NaN                  8.0
# 1                          NaN                  8.0
# 2                          NaN                  8.0
# 3                          NaN                  8.0
# 4                          NaN                  8.0
# ...                        ...                  ...
# 3799790                    NaN                  8.0
# 3799791                    NaN                  8.0
# 3799792                    NaN                  8.0
# 3799793                    NaN                  8.0
# 3799794                    NaN                  8.0
#
#         Rodzaj pokrywy śnieżnej [kod]  Status pomiaru RPSN
# 0                                 NaN                  8.0
# 1                                 NaN                  8.0
# 2                                 NaN                  8.0
# 3                                 NaN                  8.0
# 4                                 NaN                  8.0
# ...                               ...                  ...
# 3799790                             .                  NaN
# 3799791                             .                  NaN
# 3799792                             .                  NaN
# 3799793                             .                  NaN
# 3799794                             .                  NaN
#
# [3799795 rows x 16 columns]

# %%
csv_file = "dane.csv"
zip_file = "dane.zip"

dane.to_csv(csv_file, index=False)
with ZipFile(zip_file, 'w') as zf:
    zf.write(csv_file, arcname="dane.csv")
